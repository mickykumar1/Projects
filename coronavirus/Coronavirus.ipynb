# %% [markdown]
# # Coronavirus

# %% [markdown]
# ## By Micky Kumar

# %% [markdown]
# <img src ="C:/Users/Micky/Documents/project/Projects/pic/1.jpg">

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from pandas.plotting import andrews_curves

# %% [markdown]
# ## TOC:
# * [About the Dataset](#About-the-Dataset)
#     * [About the Coronavirus](#About-the-Coronavirus)
#         * [Symptoms](#Symptoms)
#     * [Type of features](#Type-of-features)
# * [Load](#Load)
# * [Explore](#Explore)
#     * [Missing Data](#Missing-Data)
#     * [matplotlib](#matplotlib)
# * [Model](#Model)

# %% [markdown]
# ## About the Dataset

# %% [markdown]
# The data that used in this from kaggle and it is called COVID-19 Open Research Dataset Challenge (CORD-19). The file was last updated on 2020-03-30.
#
# The link for this dataset is https://datahub.io/core/covid-19#data

# %% [markdown]
# ### About the Coronavirus

# %% [markdown]
# #### Symptoms

# %% [markdown]
# Symptoms have included:
#
# * cough
# * fever
# * difficulty breathing
# * pneumonia in both lungs

# %% [markdown]
# ### Type of features

# %% [markdown]
# #### time-series-19-covid-combined

# %% [markdown]
# Date: The date that occur
#
# Country: List of country
#
# Province/State: The provice that occured
#
# Lat: The latuide
#
# Long

# %% [markdown]
# ## Load

# %%
#upload and print countries aggreated file
ca  = pd.read_csv('C:/Users/Micky/Documents/project/Projects/_data/Coronavirus/countries-aggregated_csv.csv')
ca
ca.shape
# Out:
# (12282, 5)

# %%
#upload and print key countries pivoted file
kcp  = pd.read_csv('C:/Users/Micky/Documents/project/Projects/_data/Coronavirus/key-countries-pivoted_csv.csv')
kcp.shape
# Out:
# (69, 9)

# %%
#upload and print Time-series 19-covid combined file
ts19cc  = pd.read_csv('C:/Users/Micky/Documents/project/Projects/_data/Coronavirus/time-series-19-covid-combined_csv.csv')
ts19cc.shape
# Out:
# (17526, 8)

# %%
#upload and print Worldwide aggregated csv file
wwa  = pd.read_csv('C:/Users/Micky/Documents/project/Projects/_data/Coronavirus/worldwide-aggregated_csv.csv')
wwa.shape
# Out:
# (69, 5)

# %% [markdown]
# ## Explore

# %%
#ca.list

# %%
ca.tail(20)
# Out:
#              Date               Country  Confirmed  Recovered  Deaths
# 12262  2020-03-30               Taiwan*        306         39       5
# 12263  2020-03-30              Tanzania         19          1       0
# 12264  2020-03-30              Thailand       1524        229       9
# 12265  2020-03-30           Timor-Leste          1          0       0
# 12266  2020-03-30                  Togo         30          1       1
# 12267  2020-03-30   Trinidad and Tobago         82          1       3
# 12268  2020-03-30               Tunisia        312          3       8
# 12269  2020-03-30                Turkey      10827        162     168
# 12270  2020-03-30                    US     161807       5644    2978
# 12271  2020-03-30                Uganda         33          0       0
# 12272  2020-03-30               Ukraine        548          8      13
# 12273  2020-03-30  United Arab Emirates        611         61       5
# 12274  2020-03-30        United Kingdom      22453        171    1411
# 12275  2020-03-30               Uruguay        310          0       1
# 12276  2020-03-30            Uzbekistan        149          7       2
# 12277  2020-03-30             Venezuela        135         39       3
# 12278  2020-03-30               Vietnam        203         55       0
# 12279  2020-03-30    West Bank and Gaza        116         18       1
# 12280  2020-03-30                Zambia         35          0       0
# 12281  2020-03-30              Zimbabwe          7          0       1

# %%
ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12282 entries, 0 to 12281
# Data columns (total 5 columns):
# Date         12282 non-null object
# Country      12282 non-null object
# Confirmed    12282 non-null int64
# Recovered    12282 non-null int64
# Deaths       12282 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 479.9+ KB

# %%
kcp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 9 columns):
# Date              69 non-null object
# China             69 non-null int64
# US                69 non-null int64
# United_Kingdom    69 non-null int64
# Italy             69 non-null int64
# France            69 non-null int64
# Germany           69 non-null int64
# Spain             69 non-null int64
# Iran              69 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 5.0+ KB

# %%
ts19cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17526 entries, 0 to 17525
# Data columns (total 8 columns):
# Date              17526 non-null object
# Country/Region    17526 non-null object
# Province/State    5451 non-null object
# Lat               17526 non-null float64
# Long              17526 non-null float64
# Confirmed         17457 non-null float64
# Recovered         16560 non-null float64
# Deaths            17457 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 1.1+ MB

# %%
wwa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 5 columns):
# Date             69 non-null object
# Confirmed        69 non-null int64
# Recovered        69 non-null int64
# Deaths           69 non-null int64
# Increase rate    68 non-null float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.8+ KB

# %% [markdown]
# ### Missing Data

# %%
print(ca.isna().sum())
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64

# %%
print(kcp.isna().sum())
# Out:
# Date              0
# China             0
# US                0
# United_Kingdom    0
# Italy             0
# France            0
# Germany           0
# Spain             0
# Iran              0
# dtype: int64

# %%
print(ts19cc.isna().sum())
# Out:
# Date                  0
# Country/Region        0
# Province/State    12075
# Lat                   0
# Long                  0
# Confirmed            69
# Recovered           966
# Deaths               69
# dtype: int64

# %%
print(wwa.isna().sum())
# Out:
# Date             0
# Confirmed        0
# Recovered        0
# Deaths           0
# Increase rate    1
# dtype: int64

# %%
sns.heatmap(ca.iloc[:, 1:].corr(), center=0);

# %% [markdown]
# ### matplotlib

# %%
# %matplotlib inline

ca.hist(bins=50, figsize=(20,15))
plt.show()

# %%
kcp.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# %matplotlib inline

ts19cc.hist(bins=50, figsize=(20,15))
plt.show()

# %%
wwa.hist(bins=50, figsize=(20,15))
plt.show()

# %%
ca.plot.scatter(x='Confirmed',
                      y='Deaths',
                      colormap='viridis' ,figsize=(18, 16))

# %%
ca.plot(kind="scatter", x="Confirmed", y="Deaths",figsize=(18, 16));

# %%
ca.plot(kind="scatter", x="Confirmed", y="Recovered",figsize=(18, 16));

# %%
wwa.plot(kind="line", x="Date", y="Confirmed",figsize=(18, 16), title="Confirmed Cases Worldwide");

# %%
wwa.plot(kind="line", x="Date", y="Deaths",figsize=(18, 16), title="Total Deaths Worldwide");

# %%
wwa.plot(kind="bar", x="Date", y="Increase rate",figsize=(18, 16), title="Increase rate from previous day in confirmed cases worldwide");

# %%
scatter_matrix(ca, alpha=0.2, figsize=(10, 16), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7ED9F7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E28D9C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E2A6E88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E39FF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EBC3D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7ED9F4C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E224608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E1A13C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7CE54888>]],
#       dtype=object)

# %%
scatter_matrix(ts19cc, alpha=0.2, figsize=(10, 16), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EAF5308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E1DCD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E1F3B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E49B588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E4E8EC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EDADB48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E270C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EC91D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EC8F908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EE55AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EBA1088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E369148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E38E288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EEAB3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EA854C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EA455C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EAD8E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EF73748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EF20848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EB46988>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E2F3508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E252908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E264C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7EED8D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E3E6E88>]],
#       dtype=object)

# %%
scatter_matrix(wwa, alpha=0.2, figsize=(10, 16), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E90AF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E54CC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E5BF208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E810C08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E625A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E5F5F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED7E579A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED00283B88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED0028C788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED002C5948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED0032DEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED00364F48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED0039F088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED003D91C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED004122C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED0044A3C8>]],
#       dtype=object)

# %% [markdown]
# #### Cubehelix

# %%
ca.plot(colormap='cubehelix')

# %% [markdown]
# ## Model
